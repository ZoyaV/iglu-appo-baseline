# %%
import gym
import iglu
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import gym
# ----> 2 import iglu
#
# File ~/.local/lib/python3.8/site-packages/iglu/__init__.py:1, in <module>
# ----> 1 from .env import IGLUEnvSpec
#
# File ~/.local/lib/python3.8/site-packages/iglu/env.py:20, in <module>
#      17 from minerl_patched.herobraine.hero.handler import Handler
#      18 from minerl_patched.env._singleagent import _SingleAgentEnv
# ---> 20 from .handlers import AgentPosObservation, FakeResetAction, \
#      21                       HotBarObservation, \
#      22                       GridObservation, \
#      23                       HotBarChoiceAction, \
#      24                       TargetGridMonitor, \
#      25                       CameraAction, \
#      26                       GridIntersectionMonitor, \
# ...
